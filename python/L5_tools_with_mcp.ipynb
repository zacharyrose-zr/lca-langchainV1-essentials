# %% [markdown]
# # Tools with MCP ⏰
#
# The Model Context Protocol (MCP) provides a standardized way to connect AI agents to external tools and data sources. Let's connect to an MCP server using `langchain-mcp-adapters`.

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables.
#
# **Databricks:** Run the `%sh` cell below first (once per cluster), then **Configure model**. `OPENAI_API_KEY` is not required.

# %% [markdown]
# ### Databricks: Claude Sonnet via Unity AI Gateway
#
# **Prerequisite:** Account admin enables Unity AI Gateway (Account Console → Previews).
#
# Models are configured in `databricks_model.py` and routed through Unity AI Gateway (no OpenAI API key).

# %%
# %sh
pip install --quiet --upgrade "typing_extensions>=4.13.0" \
  langgraph langchain langchain-core langchain-openai \
  langchain-anthropic langchain-community langchain-mcp-adapters

# %%
from databricks_model import MODEL, MODEL_FAST

# %%
from dotenv import load_dotenv
from env_utils import doublecheck_env

# Load environment variables from .env (LangSmith keys only; OPENAI_API_KEY not needed on Databricks)
load_dotenv()

# Check and print results
doublecheck_env("example.env")
# Out:
# OPENAI_API_KEY=****eJgA
# LANGSMITH_API_KEY=****2eed
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ject

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import nest_asyncio

nest_asyncio.apply()

# Connect to the mcp-time server for timezone-aware operations
# This Go-based server provides tools for current time, relative time parsing,
# timezone conversion, duration arithmetic, and time comparison
mcp_client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "npx",
            "args": ["-y", "@theo.foobar/mcp-time"],
        }
    },
)

# Load tools from the MCP server
mcp_tools = await mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")
# Out:
# Loaded 5 MCP tools: ['add_time', 'compare_time', 'convert_timezone', 'current_time', 'relative_time']

# %% [markdown]
# Create an agent with the MCP-provided time tools.

# %%
from langchain.agents import create_agent

agent_with_mcp = create_agent(
    model=MODEL,
    tools=mcp_tools,
    system_prompt="You are a helpful assistant",
)

# %% [markdown]
# Ask about the current time in San Francisco.

# %%
result = await agent_with_mcp.ainvoke(
    {"messages": [{"role": "user", "content": "What's the time in SF right now?"}]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's the time in SF right now?
# ================================== Ai Message ==================================
# Tool Calls:
#   current_time (call_yv1gmPLMpYFyDOlzfkW2hEVO)
#  Call ID: call_yv1gmPLMpYFyDOlzfkW2hEVO
#   Args:
#     format: 2006-01-02 15:04:05 MST
#     timezone: America/Los_Angeles
# ================================= Tool Message =================================
# Name: current_time
#
# 2025-10-14 08:48:37 PDT
# ================================== Ai Message ==================================
#
# It's 8:48:37 AM PDT in San Francisco right now (2025-10-14, America/Los_Angeles).
